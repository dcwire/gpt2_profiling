# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.insert(0, "..")

# %%
from gpt_profiling.trainer import train_gpt

train_gpt("checkpoints", True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gpt_profiling.trainer import train_gpt
#       3 train_gpt("checkpoints", True)
#
# ModuleNotFoundError: No module named 'gpt_profiling'
