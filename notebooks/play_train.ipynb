# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.insert(0, "..")

# %%
from gpt_profiling.trainer import train_gpt

train_gpt("checkpoints")
# Out:
# using device cuda
# total desired batch size: 8192
# => calculated gradient accumulation steps: 1
# running master process, found 1 shards for split train
# running master process, found 1 shards for split val
# Number of paramters: 123.65M
# num decayed param tensors: 50, with 124,318,464 parameters
# num non decayed parameter tensors: 98, with 121,344 parameters
# using fused adamw: True
# starting epoch 0
# step     0 | loss: 4.960012 | lr 3.0000e-04 | norm: 0.6959 | dt: 828.63ms | tok/sec:  9886.20
# step     1 | loss: 4.984759 | lr 6.0000e-04 | norm: 0.9769 | dt: 827.32ms | tok/sec:  9901.90
# step     2 | loss: 4.676386 | lr 6.0000e-04 | norm: 1.2510 | dt: 828.91ms | tok/sec:  9882.91
# step     3 | loss: 4.615870 | lr 5.9891e-04 | norm: 1.0036 | dt: 828.10ms | tok/sec:  9892.56
# step     4 | loss: 4.757331 | lr 5.9566e-04 | norm: 0.9571 | dt: 828.39ms | tok/sec:  9889.08
# step     5 | loss: 5.010816 | lr 5.9027e-04 | norm: 0.7608 | dt: 824.40ms | tok/sec:  9936.92
# ...
