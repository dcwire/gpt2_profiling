# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.insert(0, "..")

# %%
from src.trainer import train_gpt

train_gpt()
# Out:
# using device cpu
# total desired batch size: 8192
# => calculated gradient accumulation steps: 1
# running master process, found 1 shards for split train
# running master process, found 1 shards for split val
# Number of paramters: 123.65M
# num decayed param tensors: 50, with 124,318,464 parameters
# num non decayed parameter tensors: 98, with 121,344 parameters
# using fused adamw: False
# starting epoch 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from src.trainer import train_gpt
# ----> 3 train_gpt()
#
# File ~/gpt2_profiling/notebooks/../src/trainer.py:94, in train_gpt()
#      91 x, y = x.to(device), y.to(device)
#      93 with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
# ---> 94     logits, loss = model(x, y)
#      96 loss = loss / grad_accum_steps
#      97 loss_accum += loss.detach()
#
# ...
