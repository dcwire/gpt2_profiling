# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.insert(0, "..")

# %%
from src.trainer import train_gpt

train_gpt()
# Out:
# using device cuda
# total desired batch size: 8192
# => calculated gradient accumulation steps: 1
# running master process, found 1 shards for split train
# running master process, found 1 shards for split val
# Number of paramters: 123.65M
# num decayed param tensors: 50, with 124,318,464 parameters
# num non decayed parameter tensors: 98, with 121,344 parameters
# using fused adamw: True
# starting epoch 0
# step     0 | loss: 11.015717 | lr 3.0000e-04 | norm: 24.8108 | dt: 819.05ms | tok/sec:  10001.85
# step     1 | loss: 9.523849 | lr 6.0000e-04 | norm: 5.8805 | dt: 812.71ms | tok/sec:  10079.91
# step     2 | loss: 8.637005 | lr 6.0000e-04 | norm: 2.8334 | dt: 816.55ms | tok/sec:  10032.49
# step     3 | loss: 8.269051 | lr 5.9891e-04 | norm: 4.1625 | dt: 814.51ms | tok/sec:  10057.62
# step     4 | loss: 8.135763 | lr 5.9566e-04 | norm: 3.8057 | dt: 814.90ms | tok/sec:  10052.72
# step     5 | loss: 7.795235 | lr 5.9027e-04 | norm: 2.8002 | dt: 815.53ms | tok/sec:  10044.94
# ...
